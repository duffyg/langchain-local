# %%
import chromadb

client = chromadb.Client()
collection = client.get_or_create_collection(name="collection_name")
collection.add(
    documents=["document1", "document2", "document3"],
    metadatas=[{"type": "recipe"}, {"type": "article"}, {"type": "article"}],
    ids=["1", "2", "3"]
)

results = collection.query(
    query_texts=["document"],
    n_results=2,
    where={"type": "recipe"}
)

print(results)
# Out:
# Insert of existing embedding ID: 1
# Insert of existing embedding ID: 2
# Insert of existing embedding ID: 3
# Add of existing embedding ID: 1
# Add of existing embedding ID: 2
# Add of existing embedding ID: 3
# {'ids': [['1']], 'distances': [[0.4491492807865143]], 'metadatas': [[{'type': 'recipe'}]], 'embeddings': None, 'documents': [['document1']], 'uris': None, 'data': None}

# %%
# Out:
# 2024-02-24 18:48:22.155776 [W:onnxruntime:, helper.cc:67 IsInputSupported] CoreML does not support input dim > 16384. Input:embeddings.word_embeddings.weight, shape: {30522,384}
# 2024-02-24 18:48:22.156360 [W:onnxruntime:, coreml_execution_provider.cc:81 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 49 number of nodes in the graph: 323 number of nodes supported by CoreML: 231
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# Context leak detected, msgtracer returned -1
# ---------------------------------------------------------------------------
# InvalidDimensionException                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 client = chromadb.HttpClient(host='localhost', port=8000)
#       5 collection = client.get_collection(name="a-test-collection")
# ----> 7 results = collection.query(
#       8     query_texts=["document"],
#       9     n_results=2
#      10 )
#      12 print(results)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/chromadb/api/models/Collection.py:345, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, n_results, where, where_document, include)
#     343 if "data" in include and "uris" not in include:
#     344     valid_include.append("uris")
# --> 345 query_results = self._client._query(
#     346     collection_id=self.id,
#     347     query_embeddings=valid_query_embeddings,
#     348     n_results=valid_n_results,
#     349     where=valid_where,
#     350     where_document=valid_where_document,
#     351     include=include,
#     352 )
#     354 if (
#     355     "data" in include
#     356     and self._data_loader is not None
#     357     and query_results["uris"] is not None
#     358 ):
#     359     query_results["data"] = [
#     360         self._data_loader(uris) for uris in query_results["uris"]
#     361     ]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/chromadb/telemetry/opentelemetry/__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/chromadb/api/fastapi.py:586, in FastAPI._query(self, collection_id, query_embeddings, n_results, where, where_document, include)
#     572 """Gets the nearest neighbors of a single embedding"""
#     573 resp = self._session.post(
#     574     self._api_url + "/collections/" + str(collection_id) + "/query",
#     575     data=json.dumps(
#    (...)
#     583     ),
#     584 )
# --> 586 raise_chroma_error(resp)
#     587 body = resp.json()
#     589 return QueryResult(
#     590     ids=body["ids"],
#     591     distances=body.get("distances", None),
#    (...)
#     596     data=None,
#     597 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/chromadb/api/fastapi.py:647, in raise_chroma_error(resp)
#     644     pass
#     646 if chroma_error:
# --> 647     raise chroma_error
#     649 try:
#     650     resp.raise_for_status()
#
# InvalidDimensionException: Embedding dimension 384 does not match collection dimensionality 1536
